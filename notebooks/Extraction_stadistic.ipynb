# %% [markdown]
# ## Introducción
#
# El presente notebook tiene como objetivo principal la **extracción eficiente de estadísticas descriptivas clave** a partir de múltiples archivos CSV ubicados en una carpeta específica (`raw`). Este proceso se realiza mediante la biblioteca **Dask**, la cual permite trabajar de forma escalable y eficiente con conjuntos de datos de gran tamaño, incluso en entornos con recursos limitados.
#
# El propósito final de este análisis es generar un **resumen estadístico detallado de cada archivo**, abarcando tanto variables numéricas como categóricas. Estos resúmenes son exportados en formato JSON, con el fin de **facilitar la posterior generación de dataframes sintéticos** que conserven las propiedades estadísticas esenciales de los datos originales, pero con una cantidad reducida de filas. Esta estrategia es particularmente útil en escenarios de validación, benchmarking, o simulación, donde se requiere preservar la estructura y comportamiento de los datos sin necesidad de trabajar con la totalidad de los registros originales.
#
# La implementación hace uso de un enfoque *streaming y silencioso*, evitando sobrecargas en el sistema y maximizando la compatibilidad con entornos de ejecución restringidos (como máquinas con poca memoria RAM). Además, se implementa un control manual del scheduler de Dask para asegurar una ejecución secuencial predecible y controlada.

# %%
import glob
import os
import contextlib
import json
import dask
import dask.dataframe as dd
import numpy as np
import pandas as pd
from pandas.api import types as pd_types

# 1) Desactivar cualquier progreso de Dask
dask.config.set({
    'progressbar': False,         # desactiva ProgressBar()
    'scheduler': 'synchronous'    # fuerza ejecución síncrona
})

# 2) Helper para computar “silencioso” y forzando el scheduler síncrono
def silent_compute(*args, **kwargs):
    kwargs.setdefault('scheduler', 'synchronous')
    with open(os.devnull, 'w') as fnull, \
         contextlib.redirect_stdout(fnull), \
         contextlib.redirect_stderr(fnull):
        return dask.compute(*args, **kwargs)


def compute_stats_streaming(path):
    # Leer CSV en Dask
    df = dd.read_csv(path, assume_missing=True, blocksize="100MB")

    # Obtener dtypes reales
    real_dtypes = df.dtypes
    numeric_cols = [col for col, dt in real_dtypes.items() if pd_types.is_numeric_dtype(dt)]
    cat_cols     = [col for col, dt in real_dtypes.items()
                    if pd_types.is_object_dtype(dt) or pd_types.is_categorical_dtype(dt) or pd_types.is_string_dtype(dt)]

    stats = {}

    # Estadísticas para columnas numéricas
    for col in numeric_cols:
        s = df[col]
        cnt, mn, sd, mnm, mx = silent_compute(
            s.count(), s.mean(), s.std(), s.min(), s.max()
        )
        # Percentiles con conversión segura a float
        try:
            q_vals = s.astype(float).quantile([0.25, 0.5, 0.75]) \
                          .compute(scheduler='synchronous')
            q25, q50, q75 = q_vals.values
        except Exception:
            q25 = q50 = q75 = None
        nan_cnt = silent_compute(s.isna().sum())[0]
        inf_cnt = silent_compute((s == np.inf).sum())[0]
        nin_cnt = silent_compute((s == -np.inf).sum())[0]

        stats[col] = {
            'count': int(cnt),
            'mean': float(mn),
            'std': float(sd),
            'min': float(mnm),
            '25%': float(q25) if q25 is not None else None,
            '50%': float(q50) if q50 is not None else None,
            '75%': float(q75) if q75 is not None else None,
            'max': float(mx),
            'NaN': int(nan_cnt),
            'Inf': int(inf_cnt),
            '-Inf': int(nin_cnt),
        }

    # Estadísticas para columnas categóricas
    for col in cat_cols:
        s = df[col]
        cnt  = silent_compute(s.count())[0]
        uniq = silent_compute(s.nunique())[0]
        vc = s.value_counts().nlargest(1).compute(scheduler='synchronous')
        if len(vc):
            top, freq = vc.index[0], int(vc.iloc[0])
        else:
            top, freq = None, 0
        nan_cnt = silent_compute(s.isna().sum())[0]

        # Intentar longitud de cadenas
        try:
            lengths = df[col].str.len()
            mn_len, mx_len = silent_compute(lengths.mean(), lengths.max())
            stats[col] = {
                'count': int(cnt),
                'unique': int(uniq),
                'top': top,
                'freq': freq,
                'NaN': int(nan_cnt),
                'mean_length': float(mn_len),
                'max_length': int(mx_len)
            }
        except Exception:
            stats[col] = {
                'count': int(cnt),
                'unique': int(uniq),
                'top': top,
                'freq': freq,
                'NaN': int(nan_cnt)
            }

    return stats


if __name__ == '__main__':
    # Carpeta con los CSV
    folder    = r"D:\Portafolio oficial\Retail Sales Trend Analysis\data\data\raw"
    csv_files = glob.glob(os.path.join(folder, "*.csv"))

    all_stats = {}
    for path in csv_files:
        fname = os.path.basename(path)
        print(f"Procesando {fname}...")
        stats = compute_stats_streaming(path)
        all_stats[fname] = stats

    # Guardar resultados en JSON
    output_path = os.path.join(folder, 'all_stats.json')
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(all_stats, f, ensure_ascii=False, indent=4)
    print(f"Todos los resultados se han guardado en: {output_path}")
# Out:
# Procesando holidays_events.csv...
# [#####                                   ] | 14% Completed | 107.27 ms
# C:\Users\spinz\AppData\Local\Temp\ipykernel_28628\2013412933.py:34: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd_types.is_object_dtype(dt) or pd_types.is_categorical_dtype(dt) or pd_types.is_string_dtype(dt)]
# [########################################] | 100% Completed | 615.21 ms
# [########################################] | 100% Completed | 629.41 ms
# [########################################] | 100% Completed | 634.41 ms
# [########################################] | 100% Completed | 730.01 ms
# [########################################] | 100% Completed | 730.95 ms
# [########################################] | 100% Completed | 823.89 ms
# [########################################] | 100% Completed | 918.90 ms
# [########################################] | 100% Completed | 1.02 s
# [########################################] | 100% Completed | 1.03 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.92 s
# [########################################] | 100% Completed | 2.02 s
# [########################################] | 100% Completed | 2.02 s
# [########################################] | 100% Completed | 2.02 s
# [########################################] | 100% Completed | 2.02 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 2.22 s
# [########################################] | 100% Completed | 216.49 ms
# [########################################] | 100% Completed | 220.04 ms
# [########################################] | 100% Completed | 318.37 ms
# [########################################] | 100% Completed | 417.02 ms
# [########################################] | 100% Completed | 516.09 ms
# [########################################] | 100% Completed | 613.42 ms
# [########################################] | 100% Completed | 617.41 ms
# [########################################] | 100% Completed | 715.65 ms
# [########################################] | 100% Completed | 812.84 ms
# [########################################] | 100% Completed | 912.91 ms
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.21 s
# [########################################] | 100% Completed | 1.21 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.51 s
# [########################################] | 100% Completed | 1.61 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.71 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.92 s
# [########################################] | 100% Completed | 2.01 s
# [########################################] | 100% Completed | 2.11 s
# [########################################] | 100% Completed | 408.20 ms
# [########################################] | 100% Completed | 410.93 ms
# [########################################] | 100% Completed | 509.53 ms
# [########################################] | 100% Completed | 512.30 ms
# [########################################] | 100% Completed | 516.72 ms
# [########################################] | 100% Completed | 613.19 ms
# [########################################] | 100% Completed | 612.80 ms
# [########################################] | 100% Completed | 613.17 ms
# [########################################] | 100% Completed | 711.14 ms
# [########################################] | 100% Completed | 713.42 ms
# [########################################] | 100% Completed | 712.41 ms
# [########################################] | 100% Completed | 809.68 ms
# [########################################] | 100% Completed | 829.91 ms
# [########################################] | 100% Completed | 925.57 ms
# [########################################] | 100% Completed | 1.02 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 2.02 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 419.12 ms
# [########################################] | 100% Completed | 422.79 ms
# [########################################] | 100% Completed | 521.61 ms
# [########################################] | 100% Completed | 621.03 ms
# [########################################] | 100% Completed | 718.02 ms
# [########################################] | 100% Completed | 815.17 ms
# [########################################] | 100% Completed | 818.60 ms
# [########################################] | 100% Completed | 914.97 ms
# [########################################] | 100% Completed | 1.01 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.21 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.75 s
# [########################################] | 100% Completed | 1.85 s
# [########################################] | 100% Completed | 1.92 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.22 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.32 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.32 s
# [########################################] | 100% Completed | 2.32 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.42 s
# [########################################] | 100% Completed | 323.15 ms
# [########################################] | 100% Completed | 421.06 ms
# [########################################] | 100% Completed | 518.44 ms
# [########################################] | 100% Completed | 617.17 ms
# [########################################] | 100% Completed | 617.69 ms
# [########################################] | 100% Completed | 624.27 ms
# [########################################] | 100% Completed | 625.65 ms
# [########################################] | 100% Completed | 724.18 ms
# [########################################] | 100% Completed | 824.19 ms
# [########################################] | 100% Completed | 921.54 ms
# [########################################] | 100% Completed | 1.02 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.21 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.62 s
# [########################################] | 100% Completed | 2.72 s
# [########################################] | 100% Completed | 542.94 ms
# [########################################] | 100% Completed | 640.15 ms
# [########################################] | 100% Completed | 736.78 ms
# [########################################] | 100% Completed | 836.67 ms
# [########################################] | 100% Completed | 935.19 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.13 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.16 s
# [########################################] | 100% Completed | 1.26 s
# [########################################] | 100% Completed | 1.36 s
# [########################################] | 100% Completed | 1.45 s
# [########################################] | 100% Completed | 1.45 s
# [########################################] | 100% Completed | 1.55 s
# [########################################] | 100% Completed | 1.55 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.74 s
# [########################################] | 100% Completed | 1.75 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 2.05 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.17 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.34 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.73 s
# [########################################] | 100% Completed | 774.51 ms
# [########################################] | 100% Completed | 783.45 ms
# [########################################] | 100% Completed | 850.14 ms
# [########################################] | 100% Completed | 897.95 ms
# [########################################] | 100% Completed | 982.04 ms
# [########################################] | 100% Completed | 1.06 s
# [########################################] | 100% Completed | 1.06 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.16 s
# [########################################] | 100% Completed | 1.26 s
# [########################################] | 100% Completed | 1.28 s
# [########################################] | 100% Completed | 1.38 s
# [########################################] | 100% Completed | 1.47 s
# [########################################] | 100% Completed | 1.57 s
# [########################################] | 100% Completed | 1.67 s
# [########################################] | 100% Completed | 1.77 s
# [########################################] | 100% Completed | 1.77 s
# [########################################] | 100% Completed | 1.86 s
# [########################################] | 100% Completed | 1.96 s
# [########################################] | 100% Completed | 2.06 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.46 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.65 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.84 s
# [########################################] | 100% Completed | 2.88 s
# [########################################] | 100% Completed | 2.96 s
# [########################################] | 100% Completed | 2.97 s
# [########################################] | 100% Completed | 3.07 s
# [########################################] | 100% Completed | 3.16 s
# [########################################] | 100% Completed | 647.37 ms
# [########################################] | 100% Completed | 647.68 ms
# [########################################] | 100% Completed | 742.04 ms
# [########################################] | 100% Completed | 842.61 ms
# [########################################] | 100% Completed | 940.25 ms
# [########################################] | 100% Completed | 937.86 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.05 s
# [########################################] | 100% Completed | 1.15 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.27 s
# [########################################] | 100% Completed | 1.34 s
# [########################################] | 100% Completed | 1.34 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.55 s
# [########################################] | 100% Completed | 1.65 s
# [########################################] | 100% Completed | 1.75 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 1.95 s
# [########################################] | 100% Completed | 1.95 s
# [########################################] | 100% Completed | 1.99 s
# [########################################] | 100% Completed | 2.09 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.28 s
# [########################################] | 100% Completed | 2.38 s
# [########################################] | 100% Completed | 2.48 s
# [########################################] | 100% Completed | 2.46 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 2.63 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.84 s
# [########################################] | 100% Completed | 2.93 s
# [########################################] | 100% Completed | 537.63 ms
# [########################################] | 100% Completed | 628.80 ms
# [########################################] | 100% Completed | 631.14 ms
# [########################################] | 100% Completed | 727.13 ms
# [########################################] | 100% Completed | 747.58 ms
# [########################################] | 100% Completed | 841.13 ms
# [########################################] | 100% Completed | 942.40 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.15 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.35 s
# [########################################] | 100% Completed | 1.45 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.74 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.95 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.05 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 650.06 ms
# [########################################] | 100% Completed | 750.13 ms
# [########################################] | 100% Completed | 848.20 ms
# [########################################] | 100% Completed | 947.87 ms
# [########################################] | 100% Completed | 1.05 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.15 s
# [########################################] | 100% Completed | 1.15 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.35 s
# [########################################] | 100% Completed | 1.35 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.74 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 1.96 s
# [########################################] | 100% Completed | 2.05 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.77 s
# [########################################] | 100% Completed | 2.86 s
# [########################################] | 100% Completed | 2.95 s
# [########################################] | 100% Completed | 2.95 s
# [########################################] | 100% Completed | 3.05 s
# [########################################] | 100% Completed | 3.15 s
# [########################################] | 100% Completed | 3.24 s
# [########################################] | 100% Completed | 416.60 ms
# [########################################] | 100% Completed | 455.07 ms
# [########################################] | 100% Completed | 541.19 ms
# [########################################] | 100% Completed | 637.53 ms
# [########################################] | 100% Completed | 654.06 ms
# [########################################] | 100% Completed | 749.43 ms
# [########################################] | 100% Completed | 755.44 ms
# [########################################] | 100% Completed | 757.02 ms
# [########################################] | 100% Completed | 839.43 ms
# [########################################] | 100% Completed | 937.23 ms
# [########################################] | 100% Completed | 939.44 ms
# [########################################] | 100% Completed | 943.22 ms
# [########################################] | 100% Completed | 962.36 ms
# [########################################] | 100% Completed | 1.06 s
# [########################################] | 100% Completed | 1.13 s
# [########################################] | 100% Completed | 1.15 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.86 s
# [########################################] | 100% Completed | 1.86 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.06 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.34 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 726.86 ms
# [########################################] | 100% Completed | 831.12 ms
# [########################################] | 100% Completed | 926.80 ms
# [########################################] | 100% Completed | 1.03 s
# [########################################] | 100% Completed | 1.13 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.76 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.87 s
# [########################################] | 100% Completed | 1.96 s
# [########################################] | 100% Completed | 2.05 s
# [########################################] | 100% Completed | 2.06 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.34 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 2.57 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.67 s
# [########################################] | 100% Completed | 2.77 s
# [########################################] | 100% Completed | 2.83 s
# [########################################] | 100% Completed | 2.85 s
# [########################################] | 100% Completed | 2.86 s
# [########################################] | 100% Completed | 2.95 s
# [########################################] | 100% Completed | 2.95 s
# [########################################] | 100% Completed | 3.05 s
# [########################################] | 100% Completed | 3.14 s
# [########################################] | 100% Completed | 3.24 s
# [########################################] | 100% Completed | 3.25 s
# [########################################] | 100% Completed | 3.34 s
# [########################################] | 100% Completed | 537.54 ms
# [########################################] | 100% Completed | 545.59 ms
# [########################################] | 100% Completed | 547.70 ms
# [########################################] | 100% Completed | 645.64 ms
# [########################################] | 100% Completed | 745.66 ms
# [########################################] | 100% Completed | 843.33 ms
# [########################################] | 100% Completed | 940.83 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.05 s
# [########################################] | 100% Completed | 1.07 s
# [########################################] | 100% Completed | 1.17 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.34 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.45 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.74 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 1.95 s
# [########################################] | 100% Completed | 2.05 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.84 s
# [########################################] | 100% Completed | 2.94 s
# [########################################] | 100% Completed | 3.03 s
# [########################################] | 100% Completed | 322.64 ms
# [########################################] | 100% Completed | 422.82 ms
# [########################################] | 100% Completed | 433.33 ms
# [########################################] | 100% Completed | 446.25 ms
# [########################################] | 100% Completed | 547.58 ms
# [########################################] | 100% Completed | 646.07 ms
# [########################################] | 100% Completed | 743.01 ms
# [########################################] | 100% Completed | 840.05 ms
# [########################################] | 100% Completed | 939.93 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.24 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.92 s
# [########################################] | 100% Completed | 2.02 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.32 s
# [########################################] | 100% Completed | 2.34 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.65 s
# [########################################] | 100% Completed | 2.73 s
# [########################################] | 100% Completed | 2.83 s
# [########################################] | 100% Completed | 544.06 ms
# [########################################] | 100% Completed | 638.99 ms
# [########################################] | 100% Completed | 735.82 ms
# [########################################] | 100% Completed | 833.22 ms
# [########################################] | 100% Completed | 930.65 ms
# [########################################] | 100% Completed | 1.03 s
# [########################################] | 100% Completed | 1.06 s
# [########################################] | 100% Completed | 1.06 s
# [########################################] | 100% Completed | 1.16 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.25 s
# [########################################] | 100% Completed | 1.34 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.54 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.82 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.05 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.25 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 322.86 ms
# [########################################] | 100% Completed | 422.38 ms
# [########################################] | 100% Completed | 521.94 ms
# [########################################] | 100% Completed | 621.12 ms
# [########################################] | 100% Completed | 720.26 ms
# [########################################] | 100% Completed | 819.91 ms
# [########################################] | 100% Completed | 918.11 ms
# [########################################] | 100% Completed | 931.24 ms
# [########################################] | 100% Completed | 931.70 ms
# [########################################] | 100% Completed | 1.02 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.41 s
# [########################################] | 100% Completed | 1.41 s
# [########################################] | 100% Completed | 1.51 s
# [########################################] | 100% Completed | 1.51 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.32 s
# [########################################] | 100% Completed | 2.42 s
# [########################################] | 100% Completed | 723.81 ms
# [########################################] | 100% Completed | 737.97 ms
# [########################################] | 100% Completed | 836.28 ms
# [########################################] | 100% Completed | 934.79 ms
# [########################################] | 100% Completed | 937.89 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.13 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.43 s
# [########################################] | 100% Completed | 1.44 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.76 s
# [########################################] | 100% Completed | 1.86 s
# [########################################] | 100% Completed | 1.95 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.33 s
# ...
# [########################################] | 100% Completed | 2.06 s
# [########################################] | 100% Completed | 2.09 s
# [########################################] | 100% Completed | 2.18 s
# [########################################] | 100% Completed | 2.27 s
# [########################################] | 100% Completed | 2.36 s
# [########################################] | 100% Completed | 2.36 s
# [########################################] | 100% Completed | 2.44 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.62 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.83 s
# [########################################] | 100% Completed | 2.92 s
# [########################################] | 100% Completed | 3.02 s
# [########################################] | 100% Completed | 3.02 s
# [########################################] | 100% Completed | 3.02 s
# [########################################] | 100% Completed | 3.12 s
# [########################################] | 100% Completed | 3.20 s
# [########################################] | 100% Completed | 3.30 s
# [########################################] | 100% Completed | 3.40 s
# [########################################] | 100% Completed | 3.40 s
# [########################################] | 100% Completed | 3.40 s
# [########################################] | 100% Completed | 3.48 s
# [########################################] | 100% Completed | 958.42 ms
# [########################################] | 100% Completed | 1.00 s
# [########################################] | 100% Completed | 1.06 s
# [########################################] | 100% Completed | 1.15 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.38 s
# [########################################] | 100% Completed | 1.46 s
# [########################################] | 100% Completed | 1.55 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.68 s
# [########################################] | 100% Completed | 1.76 s
# [########################################] | 100% Completed | 1.80 s
# [########################################] | 100% Completed | 1.89 s
# [########################################] | 100% Completed | 1.98 s
# [########################################] | 100% Completed | 2.07 s
# [########################################] | 100% Completed | 2.11 s
# [########################################] | 100% Completed | 2.18 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.32 s
# [########################################] | 100% Completed | 2.42 s
# [########################################] | 100% Completed | 2.51 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.64 s
# [########################################] | 100% Completed | 2.69 s
# [########################################] | 100% Completed | 2.78 s
# [########################################] | 100% Completed | 2.78 s
# [########################################] | 100% Completed | 2.87 s
# [########################################] | 100% Completed | 2.92 s
# [########################################] | 100% Completed | 2.92 s
# [########################################] | 100% Completed | 2.98 s
# [########################################] | 100% Completed | 3.07 s
# [########################################] | 100% Completed | 3.13 s
# [########################################] | 100% Completed | 3.22 s
# [########################################] | 100% Completed | 3.27 s
# [########################################] | 100% Completed | 3.37 s
# [########################################] | 100% Completed | 3.43 s
# [########################################] | 100% Completed | 3.51 s
# [########################################] | 100% Completed | 3.60 s
# [########################################] | 100% Completed | 3.60 s
# [########################################] | 100% Completed | 3.64 s
# [########################################] | 100% Completed | 1.07 sms
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.21 s
# [########################################] | 100% Completed | 1.26 s
# [########################################] | 100% Completed | 1.36 s
# [########################################] | 100% Completed | 1.46 s
# [########################################] | 100% Completed | 1.46 s
# [########################################] | 100% Completed | 1.50 s
# [########################################] | 100% Completed | 1.51 s
# [########################################] | 100% Completed | 1.60 s
# [########################################] | 100% Completed | 1.69 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.87 s
# [########################################] | 100% Completed | 1.87 s
# [########################################] | 100% Completed | 1.97 s
# [########################################] | 100% Completed | 2.07 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.26 s
# [########################################] | 100% Completed | 2.35 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.50 s
# [########################################] | 100% Completed | 2.59 s
# [########################################] | 100% Completed | 2.65 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.74 s
# [########################################] | 100% Completed | 2.77 s
# [########################################] | 100% Completed | 2.87 s
# [########################################] | 100% Completed | 2.92 s
# [########################################] | 100% Completed | 3.02 s
# [########################################] | 100% Completed | 3.06 s
# [########################################] | 100% Completed | 3.05 s
# [########################################] | 100% Completed | 3.06 s
# [########################################] | 100% Completed | 3.16 s
# [########################################] | 100% Completed | 3.17 s
# [########################################] | 100% Completed | 3.26 s
# [########################################] | 100% Completed | 3.25 s
# [########################################] | 100% Completed | 3.35 s
# [########################################] | 100% Completed | 420.99 ms
# [########################################] | 100% Completed | 519.50 ms
# [########################################] | 100% Completed | 619.49 ms
# [########################################] | 100% Completed | 622.70 ms
# [########################################] | 100% Completed | 622.33 ms
# [########################################] | 100% Completed | 719.56 ms
# [########################################] | 100% Completed | 817.63 ms
# [########################################] | 100% Completed | 916.54 ms
# [########################################] | 100% Completed | 1.02 s
# [########################################] | 100% Completed | 1.11 s
# [########################################] | 100% Completed | 1.12 s
# [########################################] | 100% Completed | 1.21 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.45 s
# [########################################] | 100% Completed | 1.55 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.64 s
# [########################################] | 100% Completed | 1.74 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.07 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.16 s
# [########################################] | 100% Completed | 2.26 s
# [########################################] | 100% Completed | 2.36 s
# [########################################] | 100% Completed | 2.46 s
# [########################################] | 100% Completed | 2.45 s
# [########################################] | 100% Completed | 2.55 s
# [########################################] | 100% Completed | 2.65 s
# [########################################] | 100% Completed | 2.75 s
# [########################################] | 100% Completed | 2.85 s
# [########################################] | 100% Completed | 443.60 ms
# [########################################] | 100% Completed | 528.21 ms
# [########################################] | 100% Completed | 629.23 ms
# [########################################] | 100% Completed | 723.76 ms
# [########################################] | 100% Completed | 729.11 ms
# [########################################] | 100% Completed | 826.75 ms
# [########################################] | 100% Completed | 826.91 ms
# [########################################] | 100% Completed | 832.20 ms
# [########################################] | 100% Completed | 930.60 ms
# [########################################] | 100% Completed | 933.34 ms
# [########################################] | 100% Completed | 1.03 s
# [########################################] | 100% Completed | 1.13 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.33 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.63 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.73 s
# [########################################] | 100% Completed | 1.75 s
# [########################################] | 100% Completed | 1.83 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.85 s
# [########################################] | 100% Completed | 1.93 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 2.04 s
# [########################################] | 100% Completed | 2.12 s
# [########################################] | 100% Completed | 2.15 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.34 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 2.54 s
# [########################################] | 100% Completed | 627.71 ms
# [########################################] | 100% Completed | 632.45 ms
# [########################################] | 100% Completed | 728.27 ms
# [########################################] | 100% Completed | 757.38 ms
# [########################################] | 100% Completed | 752.25 ms
# [########################################] | 100% Completed | 749.73 ms
# [########################################] | 100% Completed | 842.54 ms
# [########################################] | 100% Completed | 849.47 ms
# [########################################] | 100% Completed | 944.82 ms
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.05 s
# [########################################] | 100% Completed | 1.04 s
# [########################################] | 100% Completed | 1.14 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.23 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.22 s
# [########################################] | 100% Completed | 1.32 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.42 s
# [########################################] | 100% Completed | 1.52 s
# [########################################] | 100% Completed | 1.53 s
# [########################################] | 100% Completed | 1.62 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.72 s
# [########################################] | 100% Completed | 1.75 s
# [########################################] | 100% Completed | 1.84 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 1.94 s
# [########################################] | 100% Completed | 2.03 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.13 s
# [########################################] | 100% Completed | 2.14 s
# [########################################] | 100% Completed | 2.23 s
# [########################################] | 100% Completed | 2.24 s
# [########################################] | 100% Completed | 2.33 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.43 s
# [########################################] | 100% Completed | 2.53 s
# [########################################] | 100% Completed | 2.53 s
# Todos los resultados se han guardado en: D:\Portafolio oficial\Retail Sales Trend Analysis\data\data\raw\all_stats.json
